# %%
book = {
    "title": "Esercizi Dictionary",
    "author": "Francesco",
    "year": 2026
}
print("Titolo:", book["title"])
# Out:
# Titolo: Esercizi Dictionary

# %%
car = {}
car["brand"] = "Ford"
car["model"] = "Focus"
car["year"] = 2023

print(car)
# Out:
# {'brand': 'Ford', 'model': 'Focus', 'year': 2023}

# %%
user = {"username": "anna", "role": "editor"}
user["role"] = "admin"
print(user["role"])
# Out:
# admin

# %%
person = {
    "name": "Giacomo",
    "age" : 23
}
print(person)
person["city"] = "Catania"
print(person)
# Out:
# {'name': 'Giacomo', 'age': 23}
# {'name': 'Giacomo', 'age': 23, 'city': 'Catania'}

# %%
product = {"name": "Laptop", "price": 1200}
print(product["price"])
# Out:
# 1200

# %%
setting = {
    "theme" : "light"
}
print(setting)
setting["theme"] = "dark"
print(setting)
# Out:
# {'theme': 'light'}
# {'theme': 'dark'}

# %%
student = {"name": "Luca", "age": 22}
città = user.get("city", "Unknown")
print(città)
# Out:
# Unknown

# %%
account = {
    "username" : "Dark_Fri",
    "password" : "TiPiacissi"
}
e_mail = account.get("email", "Non si sa")
print(e_mail)
# Out:
# Non si sa

# %%
data = {"a": 1, "b": 2}
c = data.get("value", 0)
print(c)
# Out:
# 0

# %%
employee = {
    "name" : "Ermanno",
    "salary" : 3450
}
employee["salary"] = 3650
print(employee["salary"])
# Out:
# 3650

# %%
inventory = {}
inventory ["name", "quantity", "value"] = "carote", 25, 1.20
inventory ["name", "quantity", "value"] = "ryzen 7 9700X", 14, 285.30
inventory ["name", "quantity", "value"] = "sedia ergonomica tela", 4, 431.54
inventory["name", "quantity", "value"] = "ryzen 7 9700X", 11, 285.30
print(inventory)
# Out:
# {('name', 'quantity', 'value'): ('ryzen 7 9700X', 11, 285.3)}

# %%
profile = {
    "name" : "Cino",
    "email" : "cino.caroccia@example.com",
    "age" : 27
}
telefono = profile.get("phone", "Telefono non disponibile")
print(telefono)
# Out:
# Telefono non disponibile

# %%
scores = {
    "Student1" : {
        "name": "Gianluca",
        "score" : 23
    },
    "Student2" : {
        "name" : "Paolo",
        "score" : 19
    },
    "Student3" : {
        "name" : "Elisa",
        "score" : 28
    }
}

scores["Student1"]["score"] = 21
print(scores)
# Out:
# {'Student1': {'name': 'Gianluca', 'score': 21}, 'Student2': {'name': 'Paolo', 'score': 19}, 'Student3': {'name': 'Elisa', 'score': 28}}

# %%
product = {}
sconto = product.get("discount", "nessuno sconto disponibile")
print(sconto)
# Out:
# nessuno sconto disponibile

# %%
config = {
    "db": "scuola.db",
    "user": "admin",
    "pw": "12345",
    "voto_minimo": 18,
    "cartella": "C:/Users/Documenti/"
}
data = config.get("db", "vuoto vuotino")
print(data)

email = config.get("email", "non ce n'è email, non c'è niente")
print(email)

passaggio = config.get("voto_minimo", "da capire")
print(passaggio)
# Out:
# scuola.db
# non ce n'è email, non c'è niente
# 18
